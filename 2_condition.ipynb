# %% [markdown]
# <a href="https://colab.research.google.com/github/Antriksh991/Python/blob/main/2_condition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Check whether 15 is greater than 10.

# %%
print ( 15 > 10)
# Out:
# True

# %% [markdown]
# Check whether 5 is less than 20.

# %%
print (  5 < 20)
# Out:
# True

# %% [markdown]
# Check whether 10 is equal to 10.

# %%
print( 10 == 10)
# Out:
# True

# %% [markdown]
# Check whether 25 is not equal to 30.

# %%
print(25 != 30)
# Out:
# True

# %% [markdown]
# Check whether 50 is greater than or equal to 40.

# %%
print(50 >= 40)
# Out:
# True

# %% [markdown]
# Check whether 30 is less than or equal to 30.

# %%
print(30 <= 30)
# Out:
# True

# %% [markdown]
# Create a variable age = 20 and check whether the age is greater than or equal to 18.

# %%
age = 20
print(age >= 18)
# Out:
# True

# %% [markdown]
# Create a variable `marks = 35` and check whether marks are greater than or equal to 40.

# %%
marks = 35
print(marks >=40)
# Out:
# False

# %% [markdown]
# Create two variables:

# %%
a = 10
b = 20

# %% [markdown]
# Check whether a is less than b.

# %%
a = 10
b = 20
print(a < b)
# Out:
# True

# %% [markdown]
# Create:

# %%
x = 50

# %% [markdown]
# Check whether x is equal to 50.

# %%
x = 50
print(x == 50)
# Out:
# True

# %% [markdown]
# Create two variables: num1 = 100 and num2 = 50. Check whether num1 is greater than num2.

# %%
num1 = 100
num2 = 50
print(num1 > num2)
# Out:
# True

# %% [markdown]
# Check whether the string 'apple' is equal to the string 'apple'.

# %%
print('apple' == 'apple')
# Out:
# True

# %% [markdown]
# Create a variable current_temp = 20. Check whether current_temp is not equal to 25.

# %%
current_temp = 20
print(current_temp != 25)
# Out:
# True

# %% [markdown]
# Check whether 7 is less than or equal to 7.

# %%
print (7<=7)
# Out:
# True

# %% [markdown]
# Create a variable score = 95. Check whether score is greater than 90.

# %%
score = 95
print (score>=90)
# Out:
# True

# %% [markdown]
# Create a variable is_raining = True. Check whether is_raining is equal to False.

# %%
is_raining = True
print(is_raining == False)
# Out:
# False

# %% [markdown]
# Create a variable item_count = 0. Check whether item_count is less than 1.

# %%
item_count = 0
print(item_count < 1)
# Out:
# True

# %% [markdown]
# Create a variable price = 20.50. Check whether price is greater than or equal to 20.

# %%
price = 20.50
print(price <=20)
# Out:
# False

# %% [markdown]
# Create two string variables: city1 = 'London' and city2 = 'Paris'. Check whether city1 is not equal to city2.

# %%
city1 = 'London'
city2 = 'Paris'
print(city1 != city2)
# Out:
# True

# %% [markdown]
# Create a variable year = 2024. Check whether year is equal to 2024.

# %%
year = 2024
print( year == 2024 )
# Out:
# True
