# %% [markdown]
# <a href="https://colab.research.google.com/github/Antriksh991/Python/blob/main/1_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Operator:-

# %% [markdown]
# Q1:Calculate the sum of a and b where a= 10 and b = 5.

# %%
a = 10
b = 5
print(a+b)
# Out:
# 15

# %% [markdown]
# Q.2 find the remainder when 17 is divided by 3.

# %%
 17%3
# Out:
# 2

# %% [markdown]
# Q.3 Check if x is greater then y where x =25 and y = 20

# %%
 x = 25
 y = 20
 x<y
# Out:
# False

# %% [markdown]
# Q.4 check if p is equal to q where p = 'Abhii' and q = 'Abhii'.

# %%
 p = 'abhii'
 q =y 'abhii'
 p==q
# Out:
# True

# %% [markdown]
# Q. Evaluate (True and False).

# %%
print(True and False)
# Out:
# False

# %% [markdown]
# Q. Evaluate (True or False).

# %%
print(True or False)
# Out:
# True

# %% [markdown]
# Assign the value 10 to num and then add 4 to num using an assignment operator

# %%
num = 10
num += 4
print(num)
# Out:
# 14

# %% [markdown]
# Check if the number 5 is present in the list [1,2,3,4,5].

# %%
a = [1,2,3,4,5]
(5 in a)
# Out:
# True

# %% [markdown]
# what is the result of 10 // 3?

# %%
print(10//3)
# Out:
# 3

# %% [markdown]
# calculate 2 raised to the power of 3.

# %%
print (2 ** 3)
# Out:
# 8

# %% [markdown]
# Given x = 7 and y = 2.
# calculate (x * y) - (x % y).

# %%
x = 7
y = 2
print((x *y) - (x)
